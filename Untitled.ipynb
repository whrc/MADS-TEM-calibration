# %% [markdown]
# ## SA STEP1 TK

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import utils as ut
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
cat data/sa-cmax-TK-05/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# cmax,"[65.0, 195.0]",130.0,5,0
# cmax,"[30.0, 90.0]",60.0,5,1
# cmax,"[100.0, 300.0]",200.0,5,2
# cmax,"[225.0, 675.0]",450.0,5,3
# cmax,"[16.5, 49.5]",33.0,5,4
# cmax,"[150.0, 450.0]",300.0,5,5
# cmax,"[92.5, 277.5]",185.0,5,6
# cmax,"[60.0, 180.0]",120.0,5,7

# %%
path='data/sa-cmax-TK-050/'
params='sample_matrix.csv'
model='results.csv'
df_model = pd.read_csv(path+model,header=None)
df_param = pd.read_csv(path+params)
param_name = ['cmax0','cmax1','cmax2','cmax3','cmax4','cmax5','cmax6','cmax7']
df_param.columns = param_name
model_name = ['GPP0','GPP1','GPP2','GPP3','GPP4','GPP5','GPP6','GPP7']
df_model.columns = model_name

# %%
print (df_param.shape,df_model.shape)
# Out:
# (500, 8) (501, 8)

# %%
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)
ut.spaghetti_match_plot(df_param,df_model,logy=True)

# %%
path='data/sa-cmax-TK-099/'
params='sample_matrix.csv'
model='results.csv'
df_model = pd.read_csv(path+model,header=None)
df_param = pd.read_csv(path+params)
param_name = ['cmax0','cmax1','cmax2','cmax3','cmax4','cmax5','cmax6','cmax7']
df_param.columns = param_name
model_name = ['GPP0','GPP1','GPP2','GPP3','GPP4','GPP5','GPP6','GPP7']
df_model.columns = model_name

# %%
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)

# %%
cat data/sa-cmax-TK-099/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# cmax,"[1.3000000000000114, 258.7]",130.0,5,0
# cmax,"[0.6000000000000014, 119.4]",60.0,5,1
# cmax,"[2.0, 398.0]",200.0,5,2
# cmax,"[4.5, 895.5]",450.0,5,3
# cmax,"[0.3299999999999983, 65.67]",33.0,5,4
# cmax,"[3.0, 597.0]",300.0,5,5
# cmax,"[1.8499999999999943, 368.15]",185.0,5,6
# cmax,"[1.2000000000000028, 238.8]",120.0,5,7

# %%
path='data/sa-cmax-TK-090/'
params='sample_matrix.csv'
model='results.csv'
df_model = pd.read_csv(path+model,header=None)
df_param = pd.read_csv(path+params)
param_name = ['cmax0','cmax1','cmax2','cmax3','cmax4','cmax5','cmax6','cmax7']
df_param.columns = param_name
model_name = ['GPP0','GPP1','GPP2','GPP3','GPP4','GPP5','GPP6','GPP7']
df_model.columns = model_name

# %%
ut.one_to_one_match_plot(df_model)

# %%
cat data/sa-cmax-TK-090/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# cmax,"[20.0, 380.0]",200.0,5,0
# cmax,"[10.0, 190.0]",100.0,5,1
# cmax,"[30.0, 570.0]",300.0,5,2
# cmax,"[55.0, 1045.0]",550.0,5,3
# cmax,"[3.3000000000000007, 62.7]",33.0,5,4
# cmax,"[40.0, 760.0]",400.0,5,5
# cmax,"[28.5, 541.5]",285.0,5,6
# cmax,"[22.0, 418.0]",220.0,5,7

# %%
{'name': 'cmax', 'bounds': [20.0, 380.0], 'initial': 200.0, 'cmtnum': 5, 'pftnum': 0}
{'name': 'cmax', 'bounds': [10.0, 190.0], 'initial': 100.0, 'cmtnum': 5, 'pftnum': 1}
{'name': 'cmax', 'bounds': [30.0, 570.0], 'initial': 300.0, 'cmtnum': 5, 'pftnum': 2}
{'name': 'cmax', 'bounds': [55.0, 1045.0], 'initial': 550.0, 'cmtnum': 5, 'pftnum': 3}
{'name': 'cmax', 'bounds': [3.3000000000000007, 62.7], 'initial': 33.0, 'cmtnum': 5, 'pftnum': 4}
{'name': 'cmax', 'bounds': [40.0, 760.0], 'initial': 400.0, 'cmtnum': 5, 'pftnum': 5}
{'name': 'cmax', 'bounds': [28.5, 541.5], 'initial': 285.0, 'cmtnum': 5, 'pftnum': 6}
{'name': 'cmax', 'bounds': [22.0, 418.0], 'initial': 220.0, 'cmtnum': 5, 'pftnum': 7}

# %%
ut.spaghetti_match_plot(df_param,df_model)

# %%
path='data/sa-cmax-TK-06/'
params='sample_matrix.csv'
model='results.csv'
df_model = pd.read_csv(path+model,header=None)
df_param = pd.read_csv(path+params)
param_name = ['cmax0','cmax1','cmax2','cmax3','cmax4','cmax5','cmax6','cmax7']
df_param.columns = param_name
model_name = ['GPP0','GPP1','GPP2','GPP3','GPP4','GPP5','GPP6','GPP7']
df_model.columns = model_name
ut.one_to_one_match_plot(df_model)
ut.spaghetti_match_plot(df_param,df_model)
