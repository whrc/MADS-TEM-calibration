# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import utils as ut
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
def get_sa_data_step2(path):
    params='sample_matrix.csv'
    model='results.csv'
    df_model = pd.read_csv(path+model,header=None)
    output_name = ['NPP0','NPP1','NPP2','NPP3','VEGC00','VEGC01','VEGC02','VEGC03','VEGC10','VEGC11','VEGC12',\
                   'VEGC20','VEGC21','VEGC22']
    df_model.columns = output_name

    df_param= pd.read_csv(path+params)
    output_name = ['nmax0','nmax1','nmax2','nmax3','krb00','krb01','krb02','krb03','krb10','krb11','krb12',\
                   'krb20','krb21','krb22']
    df_param.columns = output_name
    return df_param,df_model

def get_sa_data_step2_cfall_VEGC(path):
    params='sample_matrix.csv'
    model='results.csv'
    df_model = pd.read_csv(path+model,header=None)
    output_name = ['VEGC00','VEGC01','VEGC02','VEGC03','VEGC10','VEGC11','VEGC12',\
                  'VEGC20','VEGC21','VEGC22']
    df_model.columns = output_name

    df_param = pd.read_csv(path+params)
    output_name = ['cfall00','cfall01','cfall02','cfall03','cfall10','cfall11','cfall12',\
                   'cfall20','cfall21','cfall22']
    df_param.columns = output_name
    return df_param,df_model

def get_sa_data_step2_cfall_NPPVEGC(path):
    params='sample_matrix.csv'
    model='results.csv'
    df_model = pd.read_csv(path+model,header=None)
    output_name = ['NPP0','NPP1','NPP2','NPP3','VEGC00','VEGC01','VEGC02','VEGC03','VEGC10','VEGC11','VEGC12',\
                  'VEGC20','VEGC21','VEGC22']
    df_model.columns = output_name

    df_param = pd.read_csv(path+params)
    output_name = ['cfall00','cfall01','cfall02','cfall03','cfall10','cfall11','cfall12',\
                   'cfall20','cfall21','cfall22']
    df_param.columns = output_name
    return df_param,df_model

# %% [markdown]
# ## Sensitivity Analysis (nmax and krb)

# %%
[df_param,df_model]=get_sa_data_step2('MD1/SA-MD1-STEP2/')

# %%
cat MD1/SA-MD1-STEP2/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# nmax,"[1, 5]",3.383716,1,0
# nmax,"[1, 5]",1.54588,1,1
# nmax,"[1, 5]",1.000042,1,2
# nmax,"[1, 5]",3.551762,1,3
# krb(0),"[-20, -0.1]",-6.0,1,0
# krb(0),"[-20, -0.1]",-3.45,1,1
# krb(0),"[-20, -0.1]",-2.95,1,2
# krb(0),"[-20, -0.1]",-4.65,1,3
# krb(1),"[-20, -0.1]",-4.88,1,0
# krb(1),"[-20, -0.1]",-5.15,1,1
# krb(1),"[-20, -0.1]",-6.65,1,2
# krb(2),"[-20, -0.1]",-8.2,1,0
# krb(2),"[-20, -0.1]",-6.2,1,1
# krb(2),"[-20, -0.1]",-3.2,1,2

# %%
ut.one_to_one_match_plot(df_model)

# %%
corr_mp=ut.get_output_param_corr(df_param,df_model,(12,10))

# %%
ut.spaghetti_match_plot(df_param,df_model)
ut.spaghetti_match_plot(df_param,df_model,logy=True)

# %%
xparams, ymodel = ut.get_params_r2_rmse(df_param,df_model,r2lim=0.962)
xparams
# Out:
#         nmax0     nmax1     nmax2     nmax3     krb00     krb01     krb02  \
# 6    3.255800  1.491831  1.045965  3.649476 -6.464655 -3.430828 -2.725561
# 55   3.120214  1.652995  0.925537  3.478800 -6.356754 -3.208443 -2.790258
# 58   3.129709  1.675994  1.074024  3.565144 -6.109531 -3.380312 -2.687309
# 63   3.058683  1.423480  1.060028  3.323415 -6.183295 -3.269346 -2.713670
# 65   3.444822  1.474171  1.024873  3.487412 -6.062457 -3.405927 -2.828735
# ..        ...       ...       ...       ...       ...       ...       ...
# 905  3.093940  1.420440  1.016617  3.233284 -5.804312 -3.624708 -2.828665
# 914  3.602844  1.540021  1.034849  3.505578 -6.070468 -3.145052 -3.065795
# 948  3.162050  1.577202  1.042481  3.421820 -6.047408 -3.581735 -2.903590
# 960  3.301270  1.622477  1.082625  3.732853 -5.672552 -3.717932 -2.883673
# 999  3.051831  1.479050  0.923899  3.269616 -5.492985 -3.514349 -2.766715
#
#         krb03     krb10     krb11     krb12     krb20     krb21     krb22  \
# ...

# %%
xparams.describe()
# Out:
#            nmax0      nmax1      nmax2      nmax3      krb00      krb01  \
# count  62.000000  62.000000  62.000000  62.000000  62.000000  62.000000
# mean    3.359709   1.535373   1.012593   3.504593  -6.073877  -3.442974
# std     0.233803   0.079941   0.059186   0.193735   0.323653   0.202146
# min     3.049437   1.393905   0.914591   3.219313  -6.588399  -3.791906
# 25%     3.150273   1.479227   0.954579   3.346451  -6.356456  -3.581419
# 50%     3.284684   1.532457   1.026188   3.481234  -6.109148  -3.452117
# 75%     3.599950   1.591819   1.061940   3.651702  -5.811696  -3.276326
# max     3.717237   1.695787   1.096980   3.899445  -5.400947  -3.122781
#
#            krb02      krb03      krb10      krb11      krb12      krb20  \
# count  62.000000  62.000000  62.000000  62.000000  62.000000  62.000000
# mean   -2.949093  -4.615670  -5.143681  -5.040060  -6.827263  -8.089537
# std     0.194480   0.228118   0.062799   0.254494   0.302974   0.447719
# ...

# %%
ut.plot_hist_dist(xparams)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7f4264dc5fb3> in <module>
# ----> 1 ut.plot_hist_dist(xparams)
#
# ~/projects/MADS-TEM-calibration/utils.py in plot_hist_dist(df)
#     342     i=0
#     343     for ilist in df.columns:
# --> 344         df[ilist].plot(ax=axes[i], kind='hist', ec='k')
#     345         df[ilist].plot(ax=axes[i+1], kind='kde',linewidth=2)
#     346         axes[i].set_title(ilist, fontsize=12)
#
# /Users/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /Users/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %% [markdown]
# ### SA STEP2 bnd1

# %%
[df_param,df_model]=get_sa_data_step2('data/SA-MD1-STEP2_bnd1/')
# !cat data/SA-MD1-STEP2_bnd1/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# nmax,"[2, 4]",3.383716,1,0
# nmax,"[1, 3]",1.54588,1,1
# nmax,"[0.5, 1.5]",1.000042,1,2
# nmax,"[0.1, 5]",3.551762,1,3
# krb(0),"[-20, -0.1]",-6.0,1,0
# krb(0),"[-4, -3]",-3.45,1,1
# krb(0),"[-20, -0.1]",-2.95,1,2
# krb(0),"[-20, -0.1]",-4.65,1,3
# krb(1),"[-6, -2]",-4.88,1,0
# krb(1),"[-5, -0.1]",-5.15,1,1
# krb(1),"[-20, -0.1]",-6.65,1,2
# krb(2),"[-10, -0.1]",-8.2,1,0
# krb(2),"[-20, -0.1]",-6.2,1,1
# krb(2),"[-4, -1]",-3.2,1,2

# %%
ut.one_to_one_match_plot(df_model)

# %% [markdown]
# ### SA STEP2 bnd2

# %%
cat data/SA-MD1-STEP2_bnd2/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# nmax,"[2, 4]",3.383716,1,0
# nmax,"[1, 3]",1.54588,1,1
# nmax,"[0.5, 1.5]",1.000042,1,2
# nmax,"[0.1, 5]",3.551762,1,3
# krb(0),"[-4, -0.1]",-6.0,1,0
# krb(0),"[-4, -3]",-3.45,1,1
# krb(0),"[-30, -0.1]",-2.95,1,2
# krb(0),"[-20, -0.1]",-4.65,1,3
# krb(1),"[-6, -2]",-4.88,1,0
# krb(1),"[-5, -0.1]",-5.15,1,1
# krb(1),"[-20, -0.1]",-6.65,1,2
# krb(2),"[-10, -0.1]",-8.2,1,0
# krb(2),"[-20, -0.1]",-6.2,1,1
# krb(2),"[-4, -1]",-3.2,1,2

# %%
[df_param,df_model]=get_sa_data_step2('data/SA-MD1-STEP2_bnd2/')

# %%
ut.one_to_one_match_plot(df_model)

# %% [markdown]
# ### SA STEP2 val

# %%
cat data/SA-MD1-STEP2_val/param_props.csv
# Out:
# name,bounds,initial,cmtnum,pftnum
# nmax,"[2.325, 3.875]",3.383716,1,0
# nmax,"[1.875, 3.125]",1.54588,1,1
# nmax,"[1.875, 3.125]",1.000042,1,2
# nmax,"[1.575, 2.625]",3.551762,1,3
# krb(0),"[-4.5, -7.5]",-6.0,1,0
# krb(0),"[-2.5875, -4.3125]",-3.45,1,1
# krb(0),"[-2.2125, -3.6875]",-2.95,1,2
# krb(0),"[-3.4875, -5.8125]",-4.65,1,3
# krb(1),"[-3.66, -6.1]",-4.88,1,0
# krb(1),"[-3.863, -6.4375]",-5.15,1,1
# krb(1),"[-4.99, -8.3125]",-6.65,1,2
# krb(2),"[-6.15, -10.25]",-8.2,1,0
# krb(2),"[-4.65, -7.75]",-6.2,1,1
# krb(2),"[-2.4, -4.0]",-3.2,1,2

# %%
[df_param,df_model]=get_sa_data_step2('data/SA-MD1-STEP2_val/')
ut.one_to_one_match_plot(df_model)

# %%
#corr_mp=ut.get_output_param_corr(df_param,df_model,(12,10))

# %% [markdown]
# ### SA (cfall +-0.1) VEGC

# %%
[df_param, df_model]=get_sa_data_step2_cfall_VEGC('data/SA-STEP2-MD1-VEGC-cfall/')
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)

# %%
corr_mp=ut.get_output_param_corr(df_param,df_model,(10,6))

# %%
xparams, ymodel = ut.get_params_r2_rmse(df_param,df_model,r2lim=0.95)
xparams
# Out:
#       cfall00   cfall01   cfall02   cfall03   cfall10   cfall11   cfall12  \
# 33   0.001924  0.070279  0.076484  0.012714  0.004096  0.003063  0.004143
# 73   0.001857  0.064130  0.072005  0.013064  0.004132  0.002990  0.003648
# 83   0.001834  0.059640  0.081196  0.013773  0.004069  0.003016  0.003806
# 117  0.001814  0.067060  0.076565  0.012728  0.004135  0.003376  0.003697
# 131  0.001793  0.070102  0.081070  0.012693  0.004062  0.003302  0.003749
# 163  0.001687  0.071176  0.069373  0.012939  0.004166  0.003243  0.004019
# 201  0.001927  0.069166  0.068694  0.013106  0.004092  0.003612  0.003671
# 234  0.001629  0.069987  0.079670  0.015080  0.004064  0.003214  0.003856
# 427  0.001804  0.058932  0.079828  0.014557  0.004083  0.003433  0.004203
# 433  0.001673  0.063766  0.077104  0.013981  0.004113  0.003455  0.003666
# 437  0.001675  0.064877  0.067696  0.013941  0.004110  0.003162  0.003609
# 461  0.001674  0.070256  0.069149  0.013214  0.004146  0.003014  0.003733
#
# ...

# %% [markdown]
# ### SA (cfall +-0.5) VEGC

# %%
[df_params, df_model]=get_sa_data_step2_cfall_VEGC('data/SA-STEP2-MD1-VEGC-cfall-05/')
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)

# %%
corr_mp=ut.get_output_param_corr(df_param,df_model,(10,6))

# %%
xparams, ymodel = ut.get_params_r2_rmse(df_param,df_model,r2lim=0.965)
xparams
# Out:
#       cfall00   cfall01   cfall02   cfall03   cfall10   cfall11   cfall12  \
# 153  0.001944  0.066917  0.077330  0.013826  0.004238  0.003431  0.004035
# 208  0.001799  0.066637  0.075554  0.014729  0.004298  0.003408  0.003939
# 223  0.001930  0.068310  0.067578  0.014668  0.004233  0.002975  0.004222
# 256  0.001708  0.063096  0.067465  0.014790  0.004354  0.003499  0.003945
# 397  0.001833  0.065380  0.071136  0.014357  0.004329  0.003542  0.003846
# 429  0.001853  0.062824  0.068220  0.014039  0.004231  0.003611  0.003882
# 436  0.001822  0.062991  0.071472  0.013158  0.004305  0.003265  0.003896
# 451  0.001763  0.062445  0.076776  0.012880  0.004377  0.003493  0.003983
#
#       cfall20   cfall21   cfall22     $R^2$          RMSE      MAPE
# 153  0.011970  0.002733  0.021933  0.966983   9932.627536  0.930843
# 208  0.011757  0.002746  0.025127  0.970765   8084.579813  1.198908
# 223  0.011904  0.002978  0.024630  0.966833   9673.594994  1.247586
# ...

# %% [markdown]
# ### SA (cfall +-0.75) VEGC

# %%
[df_params, df_model]=get_sa_data_step2_cfall_NPPVEGC('data/SA-STEP2-MD1-VEGC-cfall-075/')
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)

# %%
corr_mp=ut.get_output_param_corr(df_param,df_model,(10,6))

# %%
xparams, ymodel = ut.get_params_r2_rmse(df_param,df_model,r2lim=0.965)
xparams
# Out:
#       cfall00   cfall01   cfall02   cfall03   cfall10   cfall11   cfall12  \
# 8    0.001669  0.060843  0.075523  0.013857  0.004458  0.002993  0.003822
# 38   0.001726  0.070877  0.072943  0.014460  0.004342  0.003019  0.003888
# 44   0.001946  0.070861  0.071548  0.014622  0.004347  0.003392  0.004116
# 74   0.001951  0.068019  0.071200  0.013021  0.004319  0.002992  0.004085
# 82   0.001855  0.061549  0.070930  0.013093  0.004390  0.003296  0.004294
# 256  0.001708  0.063096  0.067465  0.014790  0.004354  0.003499  0.003945
# 328  0.001861  0.069400  0.068484  0.014798  0.004326  0.003596  0.004332
# 397  0.001833  0.065380  0.071136  0.014357  0.004329  0.003542  0.003846
# 408  0.001880  0.059097  0.067657  0.014439  0.004358  0.003300  0.004093
# 425  0.001777  0.063308  0.073053  0.015223  0.004323  0.003019  0.004208
# 430  0.001881  0.071399  0.073053  0.013957  0.004400  0.003031  0.003797
# 436  0.001822  0.062991  0.071472  0.013158  0.004305  0.003265  0.003896
#
# ...

# %%
xparams.describe()
# Out:
#          cfall00    cfall01    cfall02    cfall03    cfall10    cfall11  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    0.001826   0.065568   0.071205   0.014148   0.004354   0.003245
# std     0.000090   0.004360   0.002388   0.000734   0.000043   0.000229
# min     0.001669   0.059097   0.067465   0.013021   0.004305   0.002992
# 25%     0.001765   0.062631   0.070318   0.013682   0.004325   0.003019
# 50%     0.001844   0.064344   0.071336   0.014398   0.004344   0.003281
# 75%     0.001880   0.069765   0.072970   0.014664   0.004366   0.003419
# max     0.001951   0.071399   0.075523   0.015223   0.004458   0.003596
#
#          cfall12    cfall20    cfall21    cfall22      $R^2$         RMSE  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000    12.000000
# mean    0.004027   0.012147   0.002870   0.022653   0.967894  7144.372738
# std     0.000187   0.000147   0.000161   0.001189   0.001868   700.072527
# ...

# %%
ls MD1/csv/
# Out:
# STEP1-MD1-EJ.csv               STEP3-MD1-R-EJ_model.csv
# STEP1-MD1-EJ_model.csv         STEP4-MD1-EJ.csv
# STEP1-MD1R-VB.csv              STEP4-MD1-EJ_model.csv
# STEP2-MD1-1-EJ.csv             STEP4-MD1-R-EJ.csv
# STEP2-MD1-R-1-EJ.csv           STEP4-MD1-R-EJ_model.csv
# STEP2-MD1-R-1-EJ_model.csv     STEP4-MD1-R-VB.csv
# STEP2-MD1-R-1_2-EJ.csv         STEP4-MD1-R-VB_model.csv
# STEP2-MD1-R-EJ.csv             STEP5-MD1-EJ.csv
# STEP2-MD1-R-EJ_model.csv       STEP5-MD1-EJ_model.csv
# STEP2-MD1-R-VB.csv             STEP5-MD1-P2-VB.csv
# STEP2-MD1-R-VB_model.csv       STEP5-MD1-P2-VB_model.csv
# STEP2-MD1-VB.csv               STEP5-MD1-R-EJ.csv
# STEP2-MD1-VB_model.csv         STEP5-MD1-R-EJ_model.csv
# STEP2-MD1_R-1-VB.csv           out_step1.csv
# STEP2-MD1_R-2-VB.csv           out_step2-old3.csv
# STEP3-1-CR-MD1-R-VB.csv        out_step2.csv
# STEP3-1-CR-MD1-R-VB_model.csv  param_step1.csv
# STEP3-MD1-EJ.csv               param_step2-old3.csv
# ...

# %% [markdown]
# ## Calibration (nmax and krb)

# %%
path='data/calib-step2-md1/' #10% variance
params='param_step2-md1.csv'
model='out_step2-md1.csv'
df_model = pd.read_csv(path+model)
output_name = ['NPP0','NPP1','NPP2','NPP3','VEGC00','VEGC01','VEGC02','VEGC03','VEGC10','VEGC11','VEGC12',\
               'VEGC20','VEGC21','VEGC22']
df_model.columns = output_name

df_param = pd.read_csv(path+params)
output_name = ['nmax0','nmax1','nmax2','nmax3','krb00','krb01','krb02','krb03','krb10','krb11','krb12',\
               'krb20','krb21','krb22']
df_param.columns = output_name
print(df_param.shape,df_model.shape)
# Out:
# (69, 14) (70, 14)

# %%
ut.one_to_one_match_plot(df_model)

# %%
ut.spaghetti_match_plot(df_param,df_model)
#ut.spaghetti_match_plot(df_param,df_model,logy=True)

# %%
corr_mp=ut.get_output_param_corr(df_param,df_model,(12,10))

# %%
xparams, ymodel = ut.get_params_r2_rmse(df_param,df_model,r2lim=0.96)
xparams
# Out:
#        nmax0     nmax1     nmax2     nmax3      krb00      krb01      krb02  \
# 10  3.518688  1.520903  1.327582  4.779164 -19.916327  -0.445694  -0.876710
# 11  1.077465  2.840711  3.833085  4.792026  -9.478961  -5.824153 -19.997845
# 14  1.167196  1.067587  1.002742  4.640680  -8.136621  -1.310728  -0.235624
# 32  4.437432  4.958066  1.089489  1.542695  -6.507009  -1.679239 -14.382452
# 46  1.053890  3.445967  3.190680  1.052234  -8.554521 -16.425563  -3.446422
# 48  2.590337  2.748339  2.019473  1.800793  -7.843862  -4.811001  -0.297240
# 59  1.183984  4.529449  1.013759  4.101261 -19.790968  -8.180827  -4.054477
# 67  2.679992  1.260561  4.738191  4.731330  -9.807210  -3.890803 -19.870667
#
#         krb03     krb10      krb11      krb12      krb20      krb21  \
# 10  -4.895793 -5.128306  -5.674756  -8.106335  -4.110852  -9.614882
# 11  -5.263646 -4.894166  -1.163238  -5.606908 -11.282040  -7.875961
# 14  -4.631619 -4.954355  -3.472935  -9.575233 -13.845845 -11.398955
# ...
